# %%
import os
import operator
import numpy as np
from glob import glob
from shutil import copyfile, move
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# %pwd
# Out:
# '/home/patrick/Dev/Kaggle/ncfm'

# %%
# %cd $HOME_DIR
# Out:
# [Errno 2] No such file or directory: '$HOME_DIR'
# /home/patrick/Dev/Kaggle/ncfm

# %%
MODEL_NAME = "no_name"

# %%
USE_SAMPLE = False

# %%
current_dir = os.getcwd()
HOME_DIR = current_dir

if USE_SAMPLE:
    DATA_DIR = current_dir + "/data/sample"
else:
    DATA_DIR = current_dir + "/data"

# %%
# %cd $DATA_DIR/train
for d in glob('*'):
    f = glob(d + '/*jpg')
    print(d.split('/')[0], len(f))
    
print('\nSum:', len(glob('*/*.jpg')))
# Out:
# /home/patrick/Dev/Kaggle/ncfm/data/train
# SHARK 141
# NoF 372
# YFT 588
# DOL 94
# ALB 1376
# BET 160
# LAG 54
# OTHER 240
#
# Sum: 3025

# %%
# %cd $DATA_DIR/valid
for d in glob('*'):
    f = glob(d + '/*jpg')
    print(d.split('/')[0], len(f))
    
print('\nSum:', len(glob('*/*.jpg')))
# Out:
# /home/patrick/Dev/Kaggle/ncfm/data/valid
# SHARK 35
# NoF 93
# YFT 146
# DOL 23
# ALB 343
# BET 40
# LAG 13
# OTHER 59
#
# Sum: 752

# %% [markdown]
# # Model

# %%
from keras.utils.np_utils import to_categorical
from sklearn.metrics import log_loss

# %%
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D, Input, AveragePooling2D
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator

# %%
SIZE = (320,320)

input_tensor = Input(shape=(*SIZE, 3))

base_model = VGG16(include_top=False, input_tensor=input_tensor)

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
#x = Flatten()(x)
#x = Dense(512, activation='relu')(x)
x = Dense(512, activation='relu')(x)
predictions = Dense(8, activation='softmax')(x)

model = Model(input=base_model.input, output=predictions)

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 320, 320, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Convolution2D)     (None, 320, 320, 64)  1792        input_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Convolution2D)     (None, 320, 320, 64)  36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (MaxPooling2D)       (None, 160, 160, 64)  0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block2_conv1 (Convolution2D)     (None, 160, 160, 128) 73856       block1_pool[0][0]
# ____________________________________________________________________________________________________
# block2_conv2 (Convolution2D)     (None, 160, 160, 128) 147584      block2_conv1[0][0]
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 80, 80, 128)   0           block2_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_conv1 (Convolution2D)     (None, 80, 80, 256)   295168      block2_pool[0][0]
# ____________________________________________________________________________________________________
# block3_conv2 (Convolution2D)     (None, 80, 80, 256)   590080      block3_conv1[0][0]
# ____________________________________________________________________________________________________
# block3_conv3 (Convolution2D)     (None, 80, 80, 256)   590080      block3_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 40, 40, 256)   0           block3_conv3[0][0]
# ____________________________________________________________________________________________________
# block4_conv1 (Convolution2D)     (None, 40, 40, 512)   1180160     block3_pool[0][0]
# ____________________________________________________________________________________________________
# block4_conv2 (Convolution2D)     (None, 40, 40, 512)   2359808     block4_conv1[0][0]
# ____________________________________________________________________________________________________
# block4_conv3 (Convolution2D)     (None, 40, 40, 512)   2359808     block4_conv2[0][0]
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 20, 20, 512)   0           block4_conv3[0][0]
# ____________________________________________________________________________________________________
# block5_conv1 (Convolution2D)     (None, 20, 20, 512)   2359808     block4_pool[0][0]
# ____________________________________________________________________________________________________
# block5_conv2 (Convolution2D)     (None, 20, 20, 512)   2359808     block5_conv1[0][0]
# ____________________________________________________________________________________________________
# block5_conv3 (Convolution2D)     (None, 20, 20, 512)   2359808     block5_conv2[0][0]
# ____________________________________________________________________________________________________
# block5_pool (MaxPooling2D)       (None, 10, 10, 512)   0           block5_conv3[0][0]
# ____________________________________________________________________________________________________
# globalaveragepooling2d_2 (Global (None, 512)           0           block5_pool[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 512)           262656      globalaveragepooling2d_2[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 8)             4104        dense_3[0][0]
# ====================================================================================================
# Total params: 14,981,448
# Trainable params: 266,760
# Non-trainable params: 14,714,688
# ____________________________________________________________________________________________________

# %%
import keras.backend as K


def multiclass_log_loss(y_true, y_pred, eps=1e-15):
    y_pred = K.clip(y_pred, eps, 1 - eps)
    y_pred /= K.sum(y_pred, axis=1)[:, np.newaxis]
    loss = -K.sum((y_true * K.log(y_pred)), axis=1)
    return {'log loss': K.mean(loss)}

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',
              metrics=['categorical_accuracy', 'fbeta_score', multiclass_log_loss])

# %%
N_EPOCH = 1
BATCH_SIZE = 32

idg = ImageDataGenerator(preprocessing_function=lambda frame: preprocess_input(np.expand_dims(frame, 0)))

train_flow = idg.flow_from_directory(DATA_DIR + '/train', shuffle=True, batch_size=BATCH_SIZE, target_size=SIZE)
valid_flow = idg.flow_from_directory(DATA_DIR + '/valid', shuffle=True, batch_size=BATCH_SIZE, target_size=SIZE)
test_flow = idg.flow_from_directory(DATA_DIR + '/test', shuffle=False, batch_size=BATCH_SIZE, target_size=SIZE)
# Out:
# Found 3025 images belonging to 8 classes.
# Found 752 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.

# %%
model.fit_generator(train_flow, train_flow.nb_sample, nb_epoch=1,
                    validation_data=valid_flow, nb_val_samples=valid_flow.nb_sample)
# Out:
# Epoch 1/1
# 3025/3025 [==============================] - 106s - loss: 1.6941 - categorical_accuracy: 0.6370 - fbeta_score: 0.6320 - log loss: 1.8863 - val_loss: 1.1761 - val_categorical_accuracy: 0.8019 - val_fbeta_score: 0.8008 - val_log loss: 1.3499

# %%
model.optimizer.lr=0.1
model.fit_generator(train_flow, train_flow.nb_sample, nb_epoch=4,
                    validation_data=valid_flow, nb_val_samples=valid_flow.nb_sample)
# Out:
# Epoch 1/4
# 3025/3025 [==============================] - 103s - loss: 0.9438 - categorical_accuracy: 0.8116 - fbeta_score: 0.8137 - log loss: 1.1042 - val_loss: 0.8706 - val_categorical_accuracy: 0.8404 - val_fbeta_score: 0.8445 - val_log loss: 1.0327
# Epoch 2/4
# 3025/3025 [==============================] - 99s - loss: 0.8258 - categorical_accuracy: 0.8701 - fbeta_score: 0.8715 - log loss: 0.9833 - val_loss: 0.9144 - val_categorical_accuracy: 0.8511 - val_fbeta_score: 0.8538 - val_log loss: 1.0541
# Epoch 3/4
# 3025/3025 [==============================] - 98s - loss: 0.7457 - categorical_accuracy: 0.8998 - fbeta_score: 0.9001 - log loss: 0.9027 - val_loss: 0.6543 - val_categorical_accuracy: 0.8949 - val_fbeta_score: 0.8989 - val_log loss: 0.7291
# Epoch 4/4
# 3025/3025 [==============================] - 105s - loss: 0.4058 - categorical_accuracy: 0.9055 - fbeta_score: 0.9083 - log loss: 0.4212 - val_loss: 0.4235 - val_categorical_accuracy: 0.8816 - val_fbeta_score: 0.8852 - val_log loss: 0.4235

# %%
model.optimizer.lr=0.01
model.fit_generator(train_flow, train_flow.nb_sample, nb_epoch=4,
                    validation_data=valid_flow, nb_val_samples=valid_flow.nb_sample)
# Out:
# Epoch 1/4
# 3025/3025 [==============================] - 106s - loss: 0.1800 - categorical_accuracy: 0.9425 - fbeta_score: 0.9435 - log loss: 0.1800 - val_loss: 0.3203 - val_categorical_accuracy: 0.9122 - val_fbeta_score: 0.9145 - val_log loss: 0.3203
# Epoch 2/4
# 3025/3025 [==============================] - 99s - loss: 0.1331 - categorical_accuracy: 0.9603 - fbeta_score: 0.9608 - log loss: 0.1331 - val_loss: 0.2608 - val_categorical_accuracy: 0.9348 - val_fbeta_score: 0.9411 - val_log loss: 0.2608
# Epoch 3/4
# 3025/3025 [==============================] - 100s - loss: 0.0619 - categorical_accuracy: 0.9828 - fbeta_score: 0.9820 - log loss: 0.0619 - val_loss: 0.2389 - val_categorical_accuracy: 0.9322 - val_fbeta_score: 0.9344 - val_log loss: 0.2389
# Epoch 4/4
# 3025/3025 [==============================] - 98s - loss: 0.0547 - categorical_accuracy: 0.9845 - fbeta_score: 0.9849 - log loss: 0.0547 - val_loss: 0.2016 - val_categorical_accuracy: 0.9508 - val_fbeta_score: 0.9492 - val_log loss: 0.2016

# %%
x_valid = []
y_valid = [] 
for i in range(valid_flow.nb_sample // BATCH_SIZE):
    x, y = next(valid_flow)
    x_valid.append(x)
    y_valid.append(y)

x_valid = np.concatenate(x_valid, axis=0)
y_valid = np.concatenate(y_valid, axis=0)

# %%
pred_valid = model.predict(x_valid)

# %%
log_loss(y_valid, pred_valid)
# Out:
# 0.32858472797930949

# %%
pred = model.predict_generator(test_flow, test_flow.nb_sample)
pred_clip = np.copy(pred)
pred_clip = pred_clip.clip(min=0.02, max=0.98)

# %%
files = [f.split('/')[1] for f in test_flow.filenames]
columns = list(zip(*sorted(train_flow.class_indices.items(), key=operator.itemgetter(1))))[0]
submission = pd.DataFrame(data=pred_clip, index=files, columns=columns)
submission.index.name = 'image'

submission.head()
# Out:
#                     ALB   BET   DOL   LAG       NoF  OTHER  SHARK       YFT
# image
# img_04814.jpg  0.020000  0.02  0.98  0.02  0.020000   0.02   0.02  0.020000
# img_03896.jpg  0.980000  0.02  0.02  0.02  0.020000   0.02   0.02  0.020000
# img_00030.jpg  0.881836  0.02  0.02  0.02  0.111037   0.02   0.02  0.020000
# img_03355.jpg  0.284898  0.02  0.02  0.02  0.020000   0.02   0.02  0.688395
# img_03853.jpg  0.980000  0.02  0.02  0.02  0.020000   0.02   0.02  0.020000

# %%
submission.to_csv(DATA_DIR + '/result/sub_%s.csv' % MODEL_NAME)
